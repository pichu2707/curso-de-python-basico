# %% [markdown]
# # El título de nuestro proyecto
#
# * Vamos a ver funcionamiento del Jupyter
# * Carga de archivos CSV
# * Trabajar con Pandas
#
# Estos son los puntos de trabajo que tenemos en las clases de machine Learning

# %% [markdown]
# ## Descarga de librerías

# %%
# !pip install sckit-learn
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ERROR: Could not find a version that satisfies the requirement sckit-learn (from versions: none)
# ERROR: No matching distribution found for sckit-learn
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Comenzamos con la clase y tipos de código

# %%
print("hola Mundo")
# Out:
# hola Mundo

# %%
def suma(a, b):
    c = a + b
    return c

# %%
print(suma(2,3))
# Out:
# 5

# %%
print("---------- Version de librerías ---------------------")
print("pandas-> ", pd.__version__)
print("numpy -> ", np.__version__)
print("-----------------------------------------------------")
# Out:
# ---------- Version de librerías ---------------------
# pandas->  2.0.3
# numpy ->  1.24.3
# -----------------------------------------------------

# %%
filename='nfloffenseweek3.csv'
print(filename)
# Out:
# nfloffenseweek3.csv

# %% [markdown]
# ### Apertura con librería csv y python

# %%
raw_data=open(filename, 'rt')
reader = csv.reader(raw_data, delimiter=',', quoting=csv.QUOTE_NONE)
x=list(reader)
print(x)
# Out:
# [['"rank"', '"team"', '"games"', '"points_scored"', '"total_yards"', '"offensive_plays"', '"yards_per_play"', '"turnovers_lost"', '"fumbles_lost"', '"1st_downs"', '"passes_completed"', '"passes_attempted"', '"passing_yards"', '"passing_touchdowns"', '"passing_interceptions"', '"net_yards_per_pass_attempt"', '"passing_1st_downs"', '"rushing_attempts"', '"rushing_yards"', '"rushing_touchdowns"', '"rushing_yards_per_attempt"', '"rushing_1st_downs"', '"penalties"', '"penalty_yards"', '"1st_down_penalties"', '"percentage_scoring_drives"', '"percentage_turnover_drives"', '"expected_points"'], ['"1"', '"Baltimore Ravens"', '"3"', '"99"', '"1141"', '"166"', '"6.9"', '"3"', '"1"', '"55"', '"56"', '"88"', '"735"', '"10"', '"2"', '"7.8"', '"32"', '"72"', '"406"', '"2"', '"5.6"', '"18"', '"8"', '"44"', '"5"', '"42.9"', '"8.6"', '"35.63"'], ['"2"', '"Detroit Lions"', '"3"', '"95"', '"1227"', '"203"', '"6"', '"2"', '"0"', '"63"', '"66"', '"112"', '"716"', '"7"', '"2"', '"6.2"', '"38"', '"87"', '"5
# ...

# %%
raw_data = open(filename, 'rt')
data= np.loadtxt(raw_data, delimiter=',', dtype=str)
print(data)
# Out:
# [['"rank"' '"team"' '"games"' '"points_scored"' '"total_yards"'
#   '"offensive_plays"' '"yards_per_play"' '"turnovers_lost"'
#   '"fumbles_lost"' '"1st_downs"' '"passes_completed"'
#   '"passes_attempted"' '"passing_yards"' '"passing_touchdowns"'
#   '"passing_interceptions"' '"net_yards_per_pass_attempt"'
#   '"passing_1st_downs"' '"rushing_attempts"' '"rushing_yards"'
#   '"rushing_touchdowns"' '"rushing_yards_per_attempt"'
#   '"rushing_1st_downs"' '"penalties"' '"penalty_yards"'
#   '"1st_down_penalties"' '"percentage_scoring_drives"'
#   '"percentage_turnover_drives"' '"expected_points"']
#  ['"1"' '"Baltimore Ravens"' '"3"' '"99"' '"1141"' '"166"' '"6.9"' '"3"'
#   '"1"' '"55"' '"56"' '"88"' '"735"' '"10"' '"2"' '"7.8"' '"32"' '"72"'
#   '"406"' '"2"' '"5.6"' '"18"' '"8"' '"44"' '"5"' '"42.9"' '"8.6"'
#   '"35.63"']
#  ['"2"' '"Detroit Lions"' '"3"' '"95"' '"1227"' '"203"' '"6"' '"2"' '"0"'
#   '"63"' '"66"' '"112"' '"716"' '"7"' '"2"' '"6.2"' '"38"' '"87"' '"511"'
# ...

# %%
data = pd.read_csv(filename)
print(data)
# Out:
#     rank                   team  games  points_scored  total_yards  \
# 0      1       Baltimore Ravens      3             99         1141
# 1      2          Detroit Lions      3             95         1227
# 2      3          Buffalo Bills      3             91         1324
# 3      4     Kansas City Chiefs      3             88         1122
# 4      5    Philadelphia Eagles      3             86         1341
# 5      6       Cleveland Browns      3             85         1136
# 6      7   Jacksonville Jaguars      3             84         1127
# 7      8         Miami Dolphins      3             83         1066
# 8      9        Atlanta Falcons      3             80         1063
# 9     10     Cincinnati Bengals      3             64         1016
# 10    11      Las Vegas Raiders      3             64         1040
# 11    12  Washington Commanders      3             63         1026
# 12    13      Arizona Cardinals      3             62         1060
# ...

# %%
col_name=['col1','col2','col3']
data=pd.read_csv(filename, names=col_name, delimiter= )

# %% [markdown]
# ## Ejemplo de columnas y librería

# %%
filename = 'Indian-Liver-Patient.csv'
col_name = ['age', 'gen','tbili','dbili','alkphhos','aamino','sgpt','tp','alb','ag','class']

# %%
#Cargar el dataset
df = pd.read_csv(filename, names=col_name)
df = df.drop(df.index[0])
df.head()
# Out:
#   age     gen tbili dbili alkphhos aamino sgpt   tp  alb    ag class
# 1  65  Female   0.7   0.1      187     16   18  6.8  3.3   0.9     1
# 2  62    Male  10.9   5.5      699     64  100  7.5  3.2  0.74     1
# 3  62    Male   7.3   4.1      490     60   68    7  3.3  0.89     1
# 4  58    Male     1   0.4      182     14   20  6.8  3.4     1     1
# 5  72    Male   3.9     2      195     27   59  7.3  2.4   0.4     1
